# %%
from IPython.display import Image
Image(filename='dataset-thumbnail.jpg')

# %% [markdown]
# cellular-network-performance-data
# A Comprehensive Dataset of Cellular Network Performance Metrics
# Last Updated: 2 years ago (Version 1)
#
# About this Dataset
# Unlock the potential of wireless communication with this meticulously curated dataset, capturing the intricate details of cellular network performance. This dataset offers a glimpse into the world of wireless connectivity, providing researchers, engineers, and enthusiasts with invaluable insights and analysis opportunities.
#
# Features:
#
# Signal Strength (dBm): Experience the power of wireless signals with precise measurements of signal strength, ranging from -50 dBm to -120 dBm. The signal strength indicates the intensity or amplitude of the received signal, allowing you to assess the quality and reliability of the network connection.
#
# Distance to Tower (kilometers): Gain insights into the proximity of mobile devices to cellular towers. This feature provides an estimate of the distance between the device and the tower, enabling a deeper understanding of signal propagation and coverage patterns.
#
# SNR (Signal-to-Noise Ratio): Delve into the signal quality with SNR measurements, representing the ratio between the signal power and noise power in the communication system. SNR values provide a quantitative assessment of signal clarity and robustness.
#
# Attenuation: Explore the impact of signal loss as it traverses various mediums and encounters obstacles. Attenuation measurements shed light on the signal's weakening effect due to factors such as distance, interference, and environmental conditions.
#
# Units:
#
# Signal Strength: dBm (decibel milliwatts)
# Distance to Tower: kilometers
# SNR: unitless (ratio)
# Attenuation: dB (decibels)
# The dataset is meticulously crafted, combining advanced measurement devices and techniques. Signal strength measurements were obtained using cutting-edge spectrum analyzers and field strength meters, while distance to tower estimates utilized a fusion of GPS receivers, signal propagation models, and advanced calculations. SNR measurements were conducted using state-of-the-art spectrum analyzers and signal analyzers. Attenuation measurements were obtained through power meters and network analyzers, providing valuable insights into signal loss.
#
# Embark on a journey of exploration and analysis with this comprehensive dataset, unraveling the mysteries of cellular network performance for your own use-case.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv("cellular network performance.csv")

# %%
df.head()  #display the top of the dataset
# Out:
#              Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 0  2022-01-03 17:46:13             -84.119763  25.940082        1713.800550
# 1  2022-01-04 17:29:31             -87.806131  15.937354         345.371848
# 2  2022-01-05 17:14:01            -116.575176  14.709384         259.285043
# 3  2022-01-06 16:02:29             -82.961183  21.727165         357.974004
# 4  2022-01-07 22:19:17             -85.012574  26.058158         398.006716
#
#   Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 0       urban    14.690438                2.243176         5       25
# 1        home     6.213698                5.002566         3       22
# 2        open     4.494415                8.705974         2        5
# 3        home     7.619957                7.427025         5       33
# 4       urban    10.655159                0.612071         5        8
#
#   Call Type Incoming/Outgoing
# 0      data          incoming
# ...

# %%
df.tail()  #display from the bottom of the dataset
# Out:
#                Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 458  2022-04-05 10:16:11             -77.606140  26.519150         327.551183
# 459  2022-04-06 14:43:53            -110.548728  15.147635        1503.636459
# 460  2022-04-07 17:08:49            -108.254563  20.451654        1761.584061
# 461  2022-04-08 16:01:41             -99.218386  12.254734         355.301551
# 462  2022-04-09 22:47:01             -65.124403  25.202656         145.280367
#
#     Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 458    suburban     4.005920                8.101746         9       27
# 459        open     2.652199                7.719386         5       31
# 460        open     2.071428                2.492435        10       47
# 461        open     3.378450                9.268362         3       20
# 462        open     4.730200                7.544520         9       91
#
#     Call Type Incoming/Outgoing
# ...

# %%
df.memory_usage(deep = True)  #sytem level - memory consumtion
# Out:
# Index                       132
# Timestamp                 31484
# Signal Strength (dBm)      3704
# SNR                        3704
# Call Duration (s)          3704
# Environment               25090
# Attenuation                3704
# Distance to Tower (km)     3704
# Tower ID                   3704
# User ID                    3704
# Call Type                 24765
# Incoming/Outgoing         26391
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               463 non-null    object
#  1   Signal Strength (dBm)   463 non-null    float64
#  2   SNR                     463 non-null    float64
#  3   Call Duration (s)       463 non-null    float64
#  4   Environment             463 non-null    object
#  5   Attenuation             463 non-null    float64
#  6   Distance to Tower (km)  463 non-null    float64
#  7   Tower ID                463 non-null    int64
#  8   User ID                 463 non-null    int64
#  9   Call Type               463 non-null    object
#  10  Incoming/Outgoing       463 non-null    object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 39.9+ KB

# %%
df.isna()
# Out:
#      Timestamp  Signal Strength (dBm)    SNR  Call Duration (s)  Environment  \
# 0        False                  False  False              False        False
# 1        False                  False  False              False        False
# 2        False                  False  False              False        False
# 3        False                  False  False              False        False
# 4        False                  False  False              False        False
# ..         ...                    ...    ...                ...          ...
# 458      False                  False  False              False        False
# 459      False                  False  False              False        False
# 460      False                  False  False              False        False
# 461      False                  False  False              False        False
# 462      False                  False  False              False        False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               463 non-null    object
#  1   Signal Strength (dBm)   463 non-null    float64
#  2   SNR                     463 non-null    float64
#  3   Call Duration (s)       463 non-null    float64
#  4   Environment             463 non-null    object
#  5   Attenuation             463 non-null    float64
#  6   Distance to Tower (km)  463 non-null    float64
#  7   Tower ID                463 non-null    int64
#  8   User ID                 463 non-null    int64
#  9   Call Type               463 non-null    object
#  10  Incoming/Outgoing       463 non-null    object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 39.9+ KB

# %%
sns.scatterplot(x = df["Signal Strength (dBm)"], y = df["SNR"], hue = df["Tower ID"])
# Out:
# <Axes: xlabel='Signal Strength (dBm)', ylabel='SNR'>

# %%
df.head(n=4)
# Out:
#              Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 0  2022-01-03 17:46:13             -84.119763  25.940082        1713.800550
# 1  2022-01-04 17:29:31             -87.806131  15.937354         345.371848
# 2  2022-01-05 17:14:01            -116.575176  14.709384         259.285043
# 3  2022-01-06 16:02:29             -82.961183  21.727165         357.974004
#
#   Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 0       urban    14.690438                2.243176         5       25
# 1        home     6.213698                5.002566         3       22
# 2        open     4.494415                8.705974         2        5
# 3        home     7.619957                7.427025         5       33
#
#   Call Type Incoming/Outgoing
# 0      data          incoming
# 1     voice          incoming
# 2     voice          incoming
# 3      data          outgoing

# %%
df["Environment"].nunique  #there is 4 different attribute for environment
# Out:
# <bound method IndexOpsMixin.nunique of 0         urban
# 1          home
# 2          open
# 3          home
# 4         urban
#          ...
# 458    suburban
# 459        open
# 460        open
# 461        open
# 462        open
# Name: Environment, Length: 463, dtype: object>

# %%
df["Environment"].unique()  #it has ["Urban", "home", "Open", "suburban"] environment attribute
# Out:
# array(['urban', 'home', 'open', 'suburban'], dtype=object)

# %%
df["Environment"].value_counts  #values count for this Environment attribute is given below
# Out:
# <bound method IndexOpsMixin.value_counts of 0         urban
# 1          home
# 2          open
# 3          home
# 4         urban
#          ...
# 458    suburban
# 459        open
# 460        open
# 461        open
# 462        open
# Name: Environment, Length: 463, dtype: object>

# %%
sns.scatterplot(x = df["Signal Strength (dBm)"], y = df["SNR"], hue = df["Environment"])
# Out:
# <Axes: xlabel='Signal Strength (dBm)', ylabel='SNR'>

# %% [markdown]
# ### We can see the
# #### Highest and lowest SNR
# #### Open Environment is ~ 29dBm and ~ 11dBm
# #### Urban Environment is ~ 30dBm and ~ 9dBm
# #### Home Environment is ~ 27dBm and ~ 8dBm
# #### Suburban Environment is ~ 29dBm and ~ 9dBm

# %%
df["Incoming/Outgoing"].unique()
# Out:
# array(['incoming', 'outgoing'], dtype=object)

# %%
df["Incoming/Outgoing"].value_counts() #from here we can see the max call is outgoing as compared to incoming
# Out:
# Incoming/Outgoing
# incoming    240
# outgoing    223
# Name: count, dtype: int64

# %%
df.head(n=2)
# Out:
#              Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 0  2022-01-03 17:46:13             -84.119763  25.940082        1713.800550
# 1  2022-01-04 17:29:31             -87.806131  15.937354         345.371848
#
#   Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 0       urban    14.690438                2.243176         5       25
# 1        home     6.213698                5.002566         3       22
#
#   Call Type Incoming/Outgoing
# 0      data          incoming
# 1     voice          incoming

# %%
df.describe()
# Out:
#        Signal Strength (dBm)         SNR  Call Duration (s)  Attenuation  \
# count             463.000000  463.000000         463.000000   463.000000
# mean              -84.957137   19.834262         895.324971     5.459605
# std                14.349536    5.579039         529.838188     3.502259
# min              -118.681318   10.271411          11.520904     0.042255
# 25%               -95.936519   14.857527         418.499303     2.815069
# 50%               -84.230276   19.584328         910.509884     4.758147
# 75%               -74.430044   24.648712        1362.754612     7.573055
# max               -50.122222   29.963213        1795.175137    14.939793
#
#        Distance to Tower (km)    Tower ID     User ID
# count              463.000000  463.000000  463.000000
# mean                 5.064669    5.531317   52.198704
# std                  2.956370    2.837327   27.969438
# min                  0.026375    1.000000    1.000000
# ...

# %%
type(df["User ID"].count())
# Out:
# numpy.int64

# %%
df["User ID"].count()
# Out:
# 463

# %%
sns.pairplot(data = df)

# %%
sns.histplot(data = df, x = df["SNR"],kde= True,bins= 50)
# Out:
# <Axes: xlabel='SNR', ylabel='Count'>

# %%
df.head()
# Out:
#              Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 0  2022-01-03 17:46:13             -84.119763  25.940082        1713.800550
# 1  2022-01-04 17:29:31             -87.806131  15.937354         345.371848
# 2  2022-01-05 17:14:01            -116.575176  14.709384         259.285043
# 3  2022-01-06 16:02:29             -82.961183  21.727165         357.974004
# 4  2022-01-07 22:19:17             -85.012574  26.058158         398.006716
#
#   Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 0       urban    14.690438                2.243176         5       25
# 1        home     6.213698                5.002566         3       22
# 2        open     4.494415                8.705974         2        5
# 3        home     7.619957                7.427025         5       33
# 4       urban    10.655159                0.612071         5        8
#
#   Call Type Incoming/Outgoing
# 0      data          incoming
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               463 non-null    object
#  1   Signal Strength (dBm)   463 non-null    float64
#  2   SNR                     463 non-null    float64
#  3   Call Duration (s)       463 non-null    float64
#  4   Environment             463 non-null    object
#  5   Attenuation             463 non-null    float64
#  6   Distance to Tower (km)  463 non-null    float64
#  7   Tower ID                463 non-null    int64
#  8   User ID                 463 non-null    int64
#  9   Call Type               463 non-null    object
#  10  Incoming/Outgoing       463 non-null    object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 39.9+ KB

# %%
df.isnull().count()   #there is no missing value in our dataset
# Out:
# Timestamp                 463
# Signal Strength (dBm)     463
# SNR                       463
# Call Duration (s)         463
# Environment               463
# Attenuation               463
# Distance to Tower (km)    463
# Tower ID                  463
# User ID                   463
# Call Type                 463
# Incoming/Outgoing         463
# dtype: int64

# %%
df["Call Duration (s)"].head()
# Out:
# 0    1713.800550
# 1     345.371848
# 2     259.285043
# 3     357.974004
# 4     398.006716
# Name: Call Duration (s), dtype: float64

# %%
df.head(n=5)
# Out:
#              Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 0  2022-01-03 17:46:13             -84.119763  25.940082        1713.800550
# 1  2022-01-04 17:29:31             -87.806131  15.937354         345.371848
# 2  2022-01-05 17:14:01            -116.575176  14.709384         259.285043
# 3  2022-01-06 16:02:29             -82.961183  21.727165         357.974004
# 4  2022-01-07 22:19:17             -85.012574  26.058158         398.006716
#
#   Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 0       urban    14.690438                2.243176         5       25
# 1        home     6.213698                5.002566         3       22
# 2        open     4.494415                8.705974         2        5
# 3        home     7.619957                7.427025         5       33
# 4       urban    10.655159                0.612071         5        8
#
#   Call Type Incoming/Outgoing
# 0      data          incoming
# ...

# %%
df.tail()
# Out:
#                Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 458  2022-04-05 10:16:11             -77.606140  26.519150         327.551183
# 459  2022-04-06 14:43:53            -110.548728  15.147635        1503.636459
# 460  2022-04-07 17:08:49            -108.254563  20.451654        1761.584061
# 461  2022-04-08 16:01:41             -99.218386  12.254734         355.301551
# 462  2022-04-09 22:47:01             -65.124403  25.202656         145.280367
#
#     Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 458    suburban     4.005920                8.101746         9       27
# 459        open     2.652199                7.719386         5       31
# 460        open     2.071428                2.492435        10       47
# 461        open     3.378450                9.268362         3       20
# 462        open     4.730200                7.544520         9       91
#
#     Call Type Incoming/Outgoing
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               463 non-null    object
#  1   Signal Strength (dBm)   463 non-null    float64
#  2   SNR                     463 non-null    float64
#  3   Call Duration (s)       463 non-null    float64
#  4   Environment             463 non-null    object
#  5   Attenuation             463 non-null    float64
#  6   Distance to Tower (km)  463 non-null    float64
#  7   Tower ID                463 non-null    int64
#  8   User ID                 463 non-null    int64
#  9   Call Type               463 non-null    object
#  10  Incoming/Outgoing       463 non-null    object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 39.9+ KB

# %%
df["Timestamp"]
# Out:
# 0      2022-01-03 17:46:13
# 1      2022-01-04 17:29:31
# 2      2022-01-05 17:14:01
# 3      2022-01-06 16:02:29
# 4      2022-01-07 22:19:17
#               ...
# 458    2022-04-05 10:16:11
# 459    2022-04-06 14:43:53
# 460    2022-04-07 17:08:49
# 461    2022-04-08 16:01:41
# 462    2022-04-09 22:47:01
# Name: Timestamp, Length: 463, dtype: object

# %%
import pandas as pd

# %%
df = pd.read_csv("cellular network performance.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               463 non-null    object
#  1   Signal Strength (dBm)   463 non-null    float64
#  2   SNR                     463 non-null    float64
#  3   Call Duration (s)       463 non-null    float64
#  4   Environment             463 non-null    object
#  5   Attenuation             463 non-null    float64
#  6   Distance to Tower (km)  463 non-null    float64
#  7   Tower ID                463 non-null    int64
#  8   User ID                 463 non-null    int64
#  9   Call Type               463 non-null    object
#  10  Incoming/Outgoing       463 non-null    object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 39.9+ KB

# %%
df.describe()
# Out:
#        Signal Strength (dBm)         SNR  Call Duration (s)  Attenuation  \
# count             463.000000  463.000000         463.000000   463.000000
# mean              -84.957137   19.834262         895.324971     5.459605
# std                14.349536    5.579039         529.838188     3.502259
# min              -118.681318   10.271411          11.520904     0.042255
# 25%               -95.936519   14.857527         418.499303     2.815069
# 50%               -84.230276   19.584328         910.509884     4.758147
# 75%               -74.430044   24.648712        1362.754612     7.573055
# max               -50.122222   29.963213        1795.175137    14.939793
#
#        Distance to Tower (km)    Tower ID     User ID
# count              463.000000  463.000000  463.000000
# mean                 5.064669    5.531317   52.198704
# std                  2.956370    2.837327   27.969438
# min                  0.026375    1.000000    1.000000
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Signal Strength (dBm)', 'SNR', 'Call Duration (s)',
#        'Environment', 'Attenuation', 'Distance to Tower (km)', 'Tower ID',
#        'User ID', 'Call Type', 'Incoming/Outgoing'],
#       dtype='object')

# %%
df.head()
# Out:
#              Timestamp  Signal Strength (dBm)        SNR  Call Duration (s)  \
# 0  2022-01-03 17:46:13             -84.119763  25.940082        1713.800550
# 1  2022-01-04 17:29:31             -87.806131  15.937354         345.371848
# 2  2022-01-05 17:14:01            -116.575176  14.709384         259.285043
# 3  2022-01-06 16:02:29             -82.961183  21.727165         357.974004
# 4  2022-01-07 22:19:17             -85.012574  26.058158         398.006716
#
#   Environment  Attenuation  Distance to Tower (km)  Tower ID  User ID  \
# 0       urban    14.690438                2.243176         5       25
# 1        home     6.213698                5.002566         3       22
# 2        open     4.494415                8.705974         2        5
# 3        home     7.619957                7.427025         5       33
# 4       urban    10.655159                0.612071         5        8
#
#   Call Type Incoming/Outgoing
# 0      data          incoming
# ...
