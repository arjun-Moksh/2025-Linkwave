# %%
import folium 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Bell Post commissioning CSV file/LTE_2050_Ground.csv")

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2  Cell Identity_0   Unnamed: 4  \
# 0     45967.92627  -97.338052   49.882545              NaN  45967.92627
# 1     45967.92628  -97.338052   49.882545            148.0  45967.92628
# 2     45967.92630  -97.338052   49.882545            148.0  45967.92630
# 3     45967.92631  -97.338052   49.882545            148.0  45967.92631
# 4     45967.92632  -97.338052   49.882545            148.0  45967.92632
# ...           ...         ...         ...              ...          ...
# 2458  45967.95472  -97.337529   49.883499            148.0  45967.95472
# 2459  45967.95473  -97.337529   49.883499            148.0  45967.95473
# 2460  45967.95474  -97.337529   49.883499            148.0  45967.95474
# 2461  45967.95476  -97.337529   49.883499            148.0  45967.95476
# 2462  45967.95477  -97.337529   49.883499            148.0  45967.95477
#
#       Unnamed: 5  Unnamed: 6  R0 RSRP_0   Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# ...

# %%
df.info() #all datatype is numeric
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2463 entries, 0 to 2462
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       2463 non-null   float64
#  1   Unnamed: 1       2463 non-null   float64
#  2   Unnamed: 2       2463 non-null   float64
#  3   Cell Identity_0  2462 non-null   float64
#  4   Unnamed: 4       2463 non-null   float64
#  5   Unnamed: 5       2463 non-null   float64
#  6   Unnamed: 6       2463 non-null   float64
#  7   R0 RSRP_0        2462 non-null   float64
#  8   Unnamed: 8       2463 non-null   float64
#  9   Unnamed: 9       2463 non-null   float64
#  10  Unnamed: 10      2463 non-null   float64
#  11  R0 RS-CINR_0     2462 non-null   float64
#  12  Unnamed: 12      2463 non-null   float64
#  13  Unnamed: 13      2463 non-null   float64
#  14  Unnamed: 14      2463 non-null   float64
#  15  R0 RSRQ_0        2462 non-null   float64
# dtypes: float64(16)
# ...

# %%
df.columns  #columns we have
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Cell Identity_0',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'R0 RSRP_0', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'R0 RS-CINR_0', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'R0 RSRQ_0'],
#       dtype='object')

# %%
len(df.columns)  #number of columns we have on our dataset
# Out:
# 16

# %%
df.shape #number of row and columns
# Out:
# (2463, 16)

# %%
df.head()  #reading row and column the dataset from top of 5
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Cell Identity_0   Unnamed: 4  \
# 0  45967.92627  -97.338052   49.882545              NaN  45967.92627
# 1  45967.92628  -97.338052   49.882545            148.0  45967.92628
# 2  45967.92630  -97.338052   49.882545            148.0  45967.92630
# 3  45967.92631  -97.338052   49.882545            148.0  45967.92631
# 4  45967.92632  -97.338052   49.882545            148.0  45967.92632
#
#    Unnamed: 5  Unnamed: 6  R0 RSRP_0   Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0  -97.338052   49.882545        NaN  45967.92627  -97.338052    49.882545
# 1  -97.338052   49.882545     -85.82  45967.92628  -97.338052    49.882545
# 2  -97.338052   49.882545     -86.21  45967.92630  -97.338052    49.882545
# 3  -97.338052   49.882545     -78.16  45967.92631  -97.338052    49.882545
# 4  -97.338052   49.882545     -80.39  45967.92632  -97.338052    49.882545
#
#    R0 RS-CINR_0  Unnamed: 12  Unnamed: 13  Unnamed: 14  R0 RSRQ_0
# ...

# %%
df.tail()  #reading row and columns dataset from bottom top5
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2  Cell Identity_0   Unnamed: 4  \
# 2458  45967.95472  -97.337529   49.883499            148.0  45967.95472
# 2459  45967.95473  -97.337529   49.883499            148.0  45967.95473
# 2460  45967.95474  -97.337529   49.883499            148.0  45967.95474
# 2461  45967.95476  -97.337529   49.883499            148.0  45967.95476
# 2462  45967.95477  -97.337529   49.883499            148.0  45967.95477
#
#       Unnamed: 5  Unnamed: 6  R0 RSRP_0   Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 2458  -97.337529   49.883499     -86.01  45967.95472  -97.337529    49.883499
# 2459  -97.337529   49.883499     -85.50  45967.95473  -97.337529    49.883499
# 2460  -97.337529   49.883499     -84.55  45967.95474  -97.337529    49.883499
# 2461  -97.337529   49.883499     -83.29  45967.95476  -97.337529    49.883499
# 2462  -97.337529   49.883499     -82.86  45967.95477  -97.337529    49.883499
#
# ...

# %% [markdown]
# ### There are mostly same Lattitude and Longitude in most of the columns, it depends on us how we want to organize the data, either you can drop the unwanted columns or you can label the columns, later drop it

# %% [markdown]
# ## Lets create the list of columns and rename existed columns

# %%
columns = ["cellid_cordinate", "cell_lon", "cell_lat", "PCI",
          "cellid_cordinate", "cell_lon", "cell_lat",
          "RSRP", "cellid_cordinate", "cell_lon", "cell_lat",
          "SNR", "cellid_cordinate", "cell_lon", "cell_lon",
          "RSRQ"]

# %% [markdown]
# ### Now we rename all the unnamed columns to new columns we created

# %%
df.columns = columns

# %%
df  #we can see all the columns name have been renamed with same number of columns and row
# Out:
#       cellid_cordinate   cell_lon   cell_lat    PCI  cellid_cordinate  \
# 0          45967.92627 -97.338052  49.882545    NaN       45967.92627
# 1          45967.92628 -97.338052  49.882545  148.0       45967.92628
# 2          45967.92630 -97.338052  49.882545  148.0       45967.92630
# 3          45967.92631 -97.338052  49.882545  148.0       45967.92631
# 4          45967.92632 -97.338052  49.882545  148.0       45967.92632
# ...                ...        ...        ...    ...               ...
# 2458       45967.95472 -97.337529  49.883499  148.0       45967.95472
# 2459       45967.95473 -97.337529  49.883499  148.0       45967.95473
# 2460       45967.95474 -97.337529  49.883499  148.0       45967.95474
# 2461       45967.95476 -97.337529  49.883499  148.0       45967.95476
# 2462       45967.95477 -97.337529  49.883499  148.0       45967.95477
#
#        cell_lon   cell_lat   RSRP  cellid_cordinate   cell_lon   cell_lat  \
# ...

# %% [markdown]
# #### We know that there are some null(NAN) value which we needs to remove from our data or needs to do imputation but now on this case
# #### we know how data is generated and only column 0 has NAN, so we donot perform imputation just handle by droping NAN from those rows

# %% [markdown]
# ##### Lets check the null data

# %%
df[["PCI","RSRP","RSRQ"]].isnull  #from this data we can see there is only 1 NAN value on column 0
# Out:
# <bound method DataFrame.isnull of         PCI   RSRP   RSRQ
# 0       NaN    NaN    NaN
# 1     148.0 -85.82  -9.49
# 2     148.0 -86.21  -8.71
# 3     148.0 -78.16  -8.25
# 4     148.0 -80.39 -11.12
# ...     ...    ...    ...
# 2458  148.0 -86.01  -7.91
# 2459  148.0 -85.50 -12.38
# 2460  148.0 -84.55 -11.18
# 2461  148.0 -83.29  -8.02
# 2462  148.0 -82.86 -11.45
#
# [2463 rows x 3 columns]>

# %%
df.isnull().sum()  #from this data we can see there is only 1 NAN value on column 0; it shows columns PCI, RSRP, RSRQ has 1 null value or NAN
# Out:
# cellid_cordinate    0
# cell_lon            0
# cell_lat            0
# PCI                 1
# cellid_cordinate    0
# cell_lon            0
# cell_lat            0
# RSRP                1
# cellid_cordinate    0
# cell_lon            0
# cell_lat            0
# SNR                 1
# cellid_cordinate    0
# cell_lon            0
# cell_lon            0
# RSRQ                1
# dtype: int64

# %%
df.isna() #it shows missing value or NAN in Boolean form
# Out:
#       cellid_cordinate  cell_lon  cell_lat    PCI  cellid_cordinate  cell_lon  \
# 0                False     False     False   True             False     False
# 1                False     False     False  False             False     False
# 2                False     False     False  False             False     False
# 3                False     False     False  False             False     False
# 4                False     False     False  False             False     False
# ...                ...       ...       ...    ...               ...       ...
# 2458             False     False     False  False             False     False
# 2459             False     False     False  False             False     False
# 2460             False     False     False  False             False     False
# 2461             False     False     False  False             False     False
# 2462             False     False     False  False             False     False
#
# ...
