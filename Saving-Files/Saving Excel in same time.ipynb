# %% [markdown]
# ### Saving all excel files in same time without changing any metadata

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from concurrent.futures import ThreadPoolExecutor
from openpyxl import load_workbook

# %%
folder_path = r"C:\Users\Arjun K C\Desktop\RAW FILE"

# %%
excel_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.xlsx')]

# %%
def save_excel(folder_path):
    wb = load_workbook(folder_path)
    wb.save(folder_path)
    wb.close()
    print(f"Saved: {folder_path}")

# %%
with ThreadPoolExecutor() as executor:
    executor.map(save_excel, excel_files)
# Out:
# Saved: C:\Users\Arjun K C\Desktop\RAW FILE\LTE_900_P3.xlsxSaved: C:\Users\Arjun K C\Desktop\RAW FILE\LTE_2325_P3.xlsx
#
# Saved: C:\Users\Arjun K C\Desktop\RAW FILE\LTE_2325_P1.xlsx
# Saved: C:\Users\Arjun K C\Desktop\RAW FILE\LTE_900_P1.xlsx
# Saved: C:\Users\Arjun K C\Desktop\RAW FILE\LTE_2325_P2.xlsx
# Saved: C:\Users\Arjun K C\Desktop\RAW FILE\LTE_900_P2.xlsx

# %%
import os
import time

folder_path = r"C:\Users\Arjun K C\Desktop\RAW FILE"
excel_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.xlsx')]

for file in excel_files:
    # Set current time as modification time
    os.utime(file, None)
