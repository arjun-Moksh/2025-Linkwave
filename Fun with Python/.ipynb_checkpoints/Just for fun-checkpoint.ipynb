# %% [markdown]
# ###### function with no arguments

# %%
def func():  #no arguments is passed on the defined function/also defining place holder
    pass
    

# or

def func(): #defining placeholder to work code properly
    ...

def func():  #defining function which return empty value
    return None
